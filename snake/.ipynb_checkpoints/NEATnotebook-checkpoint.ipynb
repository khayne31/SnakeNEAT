# %%
import networkx as nx

# %%
import NEAT
# Out:
# 14
# 12
# 21
# 12
# 10.594810050208546

# %%
network = NEAT.network()

# %%
network.initalize_network(8, 4)

# %%
print(network.input_nodes)
# Out:
# [<NEAT.node object at 0x0000021C2BEE2B38>, <NEAT.node object at 0x0000021C2BEE27F0>, <NEAT.node object at 0x0000021C2BEE2748>, <NEAT.node object at 0x0000021C2BEE2780>, <NEAT.node object at 0x0000021C2BEE2940>, <NEAT.node object at 0x0000021C2BEE24E0>, <NEAT.node object at 0x0000021C2BEE24A8>, <NEAT.node object at 0x0000021C2BEE26A0>]

# %%
G = nx.DiGraph()

# %%
G.add_nodes_from(network.nodes)

# %%
import matplotlib.pyplot as plt

# %%
nx.draw(G, with_labels = True)

# %%
G.clear()
for node in network.nodes:
    for connection in node.connected_to_out:
        G.add_edge(connection.input_node, connection.output_node, weight = connection.weight)
        #G.add_edge(connection.output_node, connection.input_node, weight = connection.weight)
        
labels = []
nodes = network.nodes
for node in nodes:
    labels.append(node.label)
mapping = dict(zip(nodes, labels))
G1 = nx.relabel_nodes(G, mapping)

# %%
nx.draw_shell(G1, with_labels = True)

# %%
print(len(network.nodes))
# Out:
# 12

# %%
for i in range(len(network.nodes)):
    for j in range(len(network.nodes)):
        print( not (i == j) and network.nodes[i] == network.nodes[j], i, j)
# Out:
# False 0 0
# False 0 1
# False 0 2
# False 0 3
# False 0 4
# False 0 5
# False 0 6
# False 0 7
# False 0 8
# False 0 9
# False 0 10
# False 0 11
# False 1 0
# False 1 1
# False 1 2
# False 1 3
# False 1 4
# False 1 5
# False 1 6
# False 1 7
# False 1 8
# False 1 9
# False 1 10
# False 1 11
# False 2 0
# False 2 1
# False 2 2
# False 2 3
# False 2 4
# False 2 5
# False 2 6
# False 2 7
# False 2 8
# False 2 9
# False 2 10
# False 2 11
# False 3 0
# False 3 1
# False 3 2
# False 3 3
# False 3 4
# False 3 5
# False 3 6
# False 3 7
# False 3 8
# False 3 9
# False 3 10
# False 3 11
# False 4 0
# False 4 1
# False 4 2
# False 4 3
# False 4 4
# False 4 5
# False 4 6
# False 4 7
# False 4 8
# False 4 9
# False 4 10
# False 4 11
# False 5 0
# False 5 1
# False 5 2
# False 5 3
# False 5 4
# False 5 5
# False 5 6
# False 5 7
# False 5 8
# False 5 9
# False 5 10
# False 5 11
# False 6 0
# False 6 1
# False 6 2
# False 6 3
# False 6 4
# False 6 5
# False 6 6
# False 6 7
# False 6 8
# False 6 9
# False 6 10
# False 6 11
# False 7 0
# False 7 1
# False 7 2
# False 7 3
# False 7 4
# False 7 5
# False 7 6
# False 7 7
# False 7 8
# False 7 9
# False 7 10
# False 7 11
# False 8 0
# False 8 1
# False 8 2
# False 8 3
# False 8 4
# False 8 5
# False 8 6
# False 8 7
# False 8 8
# False 8 9
# False 8 10
# False 8 11
# False 9 0
# False 9 1
# False 9 2
# False 9 3
# False 9 4
# False 9 5
# False 9 6
# False 9 7
# False 9 8
# False 9 9
# False 9 10
# False 9 11
# False 10 0
# False 10 1
# False 10 2
# False 10 3
# False 10 4
# False 10 5
# False 10 6
# False 10 7
# False 10 8
# False 10 9
# False 10 10
# False 10 11
# False 11 0
# False 11 1
# False 11 2
# False 11 3
# False 11 4
# False 11 5
# False 11 6
# False 11 7
# False 11 8
# False 11 9
# False 11 10
# False 11 11

# %%
network.generate_graph()

# %%
network.draw_graph()

# %%
network.mutation()

# %%
network.generate_graph()
network.draw_graph()

# %%
network.mutation()
network.generate_graph()
network.draw_graph()

# %%
for i in range(10):
    network.mutation()
network.generate_graph()
network.draw_graph()

# %%
G = nx.Graph()
nx.add_path(G, [0, 1, 2, 3, 4, 5, 6])
nx.add_path(G, [2, 7, 8, 9, 10])
print(dict(nx.bfs_successors(G, source=1)))
nx.draw_shell(G, with_labels = True)
# Out:
# {1: [0, 2], 2: [3, 7], 3: [4], 7: [8], 4: [5], 8: [9], 5: [6], 9: [10]}
# C:\Users\Kellen\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
