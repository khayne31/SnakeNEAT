# %%
import networkx as nx

# %%
import NEAT
# Out:
# 14
# 12
# 21
# 12
# 10.594810050208546

# %%
network = NEAT.network()

# %%
network.initalize_network(8, 4)

# %%
G = nx.DiGraph()

# %%
G.add_nodes_from(network.nodes)

# %%
import matplotlib.pyplot as plt

# %%
nx.draw(G, with_labels = True)

# %%
network.mutation()
network.generate_graph()
network.draw_graph()

# %%
for i in range(10):
    network.mutation()
network.generate_graph()
network.draw_graph()

# %%
n = NEAT.network()

# %%
n.initalize_network(4, 4, [4,5,3,9])

# %%
for i in range(30):
    n.mutation()

# %%
for output in n.output_nodes:
    output.get_value()
for node in n.nodes:
    if not node.is_input:
        value_sum = 0
        for connection in node.connected_to_in:
            if connection.enabled:
                value_sum += connection.input_node.value * connection.weight
        print(value_sum == node.value, node.label)
# Out:
# True output 4
# True output 5
# True output 6
# True output 7
# True hidden8
# True hidden9
# True hidden10
# True hidden11
# True hidden12
# True hidden13
# True hidden14

# %%
n.generate_graph()
n.draw_graph()

# %%
y = [connection for connection in n.weights]

# %%
sorted(y, key = lambda x: x.innovation_number, reverse = True)
# Out:
# [<NEAT.connection at 0x19e2c8b59e8>,
#  <NEAT.connection at 0x19e2c8b5da0>,
#  <NEAT.connection at 0x19e2c8cb908>,
#  <NEAT.connection at 0x19e2c8cb940>,
#  <NEAT.connection at 0x19e2c8cbc88>,
#  <NEAT.connection at 0x19e2c8cbe80>,
#  <NEAT.connection at 0x19e2c8cbc18>,
#  <NEAT.connection at 0x19e2c8cb9b0>,
#  <NEAT.connection at 0x19e2c8cba20>,
#  <NEAT.connection at 0x19e2c8cbeb8>,
#  <NEAT.connection at 0x19e2c8cbb38>,
#  <NEAT.connection at 0x19e2c8cbd30>,
#  <NEAT.connection at 0x19e2c8cba90>,
#  <NEAT.connection at 0x19e2c8cba58>,
#  <NEAT.connection at 0x19e2c8cbbe0>,
#  <NEAT.connection at 0x19e2c8cb208>,
#  <NEAT.connection at 0x19e2c8cb1d0>,
#  <NEAT.connection at 0x19e2c8cb198>,
#  <NEAT.connection at 0x19e2c8cb0f0>,
#  <NEAT.connection at 0x19e2c8cb0b8>,
#  <NEAT.connection at 0x19e2c8cb080>,
#  <NEAT.connection at 0x19e2c8cb390>,
#  <NEAT.connection at 0x19e2c8cb3c8>,
#  <NEAT.connection at 0x19e2c8cb400>,
#  <NEAT.connection at 0x19e2c8cb438>,
#  <NEAT.connection at 0x19e2c8cb470>,
#  <NEAT.connection at 0x19e2c8cb4a8>,
#  <NEAT.connection at 0x19e2c8cb4e0>,
#  <NEAT.connection at 0x19e2c8cb518>,
#  <NEAT.connection at 0x19e2c8cb550>,
#  <NEAT.connection at 0x19e2c8cb5c0>]

# %%
y
# Out:
# [<NEAT.connection at 0x19e2c8cb208>,
#  <NEAT.connection at 0x19e2c8cb1d0>,
#  <NEAT.connection at 0x19e2c8cb198>,
#  <NEAT.connection at 0x19e2c8cb0f0>,
#  <NEAT.connection at 0x19e2c8cb0b8>,
#  <NEAT.connection at 0x19e2c8cb080>,
#  <NEAT.connection at 0x19e2c8cb390>,
#  <NEAT.connection at 0x19e2c8cb3c8>,
#  <NEAT.connection at 0x19e2c8cb400>,
#  <NEAT.connection at 0x19e2c8cb438>,
#  <NEAT.connection at 0x19e2c8cb470>,
#  <NEAT.connection at 0x19e2c8cb4a8>,
#  <NEAT.connection at 0x19e2c8cb4e0>,
#  <NEAT.connection at 0x19e2c8cb518>,
#  <NEAT.connection at 0x19e2c8cb550>,
#  <NEAT.connection at 0x19e2c8cb5c0>,
#  <NEAT.connection at 0x19e2c8cba58>,
#  <NEAT.connection at 0x19e2c8cbbe0>,
#  <NEAT.connection at 0x19e2c8cba90>,
#  <NEAT.connection at 0x19e2c8cbb38>,
#  <NEAT.connection at 0x19e2c8cbd30>,
#  <NEAT.connection at 0x19e2c8cba20>,
#  <NEAT.connection at 0x19e2c8cbeb8>,
#  <NEAT.connection at 0x19e2c8cbc18>,
#  <NEAT.connection at 0x19e2c8cb9b0>,
#  <NEAT.connection at 0x19e2c8cbc88>,
#  <NEAT.connection at 0x19e2c8cbe80>,
#  <NEAT.connection at 0x19e2c8cb908>,
#  <NEAT.connection at 0x19e2c8cb940>,
#  <NEAT.connection at 0x19e2c8b59e8>,
#  <NEAT.connection at 0x19e2c8b5da0>]

# %%
n.convert_to_genes()

# %%
for gene in n.genes:
    print("input: ", gene.input.label)
    print("output: ", gene.output.label)
    print("innotvaion number: ", gene.innovation)
    print("DISABLED \n\n\n" if not gene.enabled else "\n\n\n")
# Out:
# input:  input 0
# output:  output 4
# innotvaion number:  0
# DISABLED
#
#
#
# input:  input 0
# output:  output 5
# innotvaion number:  0
# DISABLED
#
#
#
# input:  input 0
# output:  output 6
# innotvaion number:  0
#
#
#
#
# input:  input 0
# output:  output 7
# innotvaion number:  0
# DISABLED
#
#
#
# input:  input 1
# output:  output 4
# innotvaion number:  0
# DISABLED
#
#
#
# input:  input 1
# output:  output 5
# innotvaion number:  0
#
#
#
#
# input:  input 1
# output:  output 6
# innotvaion number:  0
# DISABLED
#
#
#
# input:  input 1
# output:  output 7
# innotvaion number:  0
#
#
#
#
# input:  input 2
# output:  output 4
# innotvaion number:  0
# DISABLED
#
#
#
# input:  input 2
# output:  output 5
# innotvaion number:  0
#
#
#
#
# input:  input 2
# output:  output 6
# innotvaion number:  0
#
#
#
#
# input:  input 2
# output:  output 7
# innotvaion number:  0
# DISABLED
#
#
#
# input:  input 3
# output:  output 4
# innotvaion number:  0
#
#
#
#
# input:  input 3
# output:  output 5
# innotvaion number:  0
#
#
#
#
# input:  input 3
# output:  output 6
# innotvaion number:  0
#
#
#
#
# input:  input 3
# output:  output 7
# innotvaion number:  0
#
#
#
#
# input:  input 1
# output:  hidden8
# innotvaion number:  1
# DISABLED
#
#
#
# input:  hidden8
# output:  output 6
# innotvaion number:  1
#
#
#
#
# input:  input 2
# output:  hidden8
# innotvaion number:  2
# DISABLED
#
#
#
# input:  input 0
# output:  hidden9
# innotvaion number:  3
#
#
#
#
# input:  hidden9
# output:  output 7
# innotvaion number:  3
#
#
#
#
# input:  input 0
# output:  hidden10
# innotvaion number:  4
#
#
#
#
# input:  hidden10
# output:  output 4
# innotvaion number:  4
#
#
#
#
# input:  input 2
# output:  hidden11
# innotvaion number:  5
#
#
#
#
# input:  hidden11
# output:  output 7
# innotvaion number:  5
#
#
#
#
# input:  input 1
# output:  hidden12
# innotvaion number:  6
#
#
#
#
# input:  hidden12
# output:  hidden8
# innotvaion number:  6
#
#
#
#
# input:  input 2
# output:  hidden13
# innotvaion number:  7
#
#
#
#
# input:  hidden13
# output:  hidden8
# innotvaion number:  7
#
#
#
#
# input:  input 2
# output:  hidden14
# innotvaion number:  8
#
#
#
#
# input:  hidden14
# output:  output 4
# innotvaion number:  8
